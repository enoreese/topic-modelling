# %%
# packages to store and manipulate data
import pandas as pd
import numpy as np

# plotting packages
import matplotlib.pyplot as plt
import seaborn as sns

# model building package
import sklearn
import spacy, gensim

# package to clean text
import re
import string

from preprocessor import TwitterPreprocessor

# %%
tweets = pd.read_csv('data/tweets.csv', index_col=0)

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                            full_text  is_retweet retweeted  \
# 0  I have taken it up with @fccpcnigeria . Hopefu...       False        []
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawaha...       False        []
# 2  @ChickenRepublic Dear @fccpcnigeria kindly advise       False        []
# 3  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
# 4  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
#
#                                            mentioned hashtags
# 0                 ['@fccpcnigeria', '@fccpcnigeria']       []
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG',...       []
# 2              ['@ChickenRepublic', '@fccpcnigeria']       []
# 3  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
# 4  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []

# %%
tweets.shape
# Out:
# (200000, 6)

# %% [markdown]
# ## Topic Modelling
#
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. In our case, the collection of document is a collection or tweets.
#
# They are various algorithms used for topic modelling. Here we would look at **LDA** (Latent Dirichlet Allocation).
#
# LDA represents documents as mixtures of topics that spit out words with certain probabilities. It assumes that documents are produced in the following fashion: when writing each document, you
#
# - Decide on the number of words N the document will have (say, according to a Poisson distribution).
# - Choose a topic mixture for the document (according to a Dirichlet distribution over a fixed set of K topics). For example, assuming that we have the two food and cute animal topics above, you might choose the document to consist of 1/3 food and 2/3 cute animals.
# - Generate each word w_i in the document by:
#     - First picking a topic (according to the multinomial distribution that you sampled above; for example, you might pick the food topic with 1/3 probability and the cute animals topic with 2/3 probability).
#     - Using the topic to generate the word itself (according to the topic’s multinomial distribution). For example, if we selected the food topic, we might generate the word “broccoli” with 30% probability, “bananas” with 15% probability, and so on.
#
# **It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.**

# %% [markdown]
# ### Cleaning Unstructured Text Data
#
# The most important thing we need to do to help our topic modelling algorithm is to pre-clean up the tweets. Looking at the tweets you may notice that they are very untidy, with non-standard English, capitalisation, links, hashtags, @users and punctuation and emoticons everywhere. In order to properly apply topic modelling we need to remove most of this and massage our data into a more standard form before finally turning it into vectors.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %% [markdown]
# Below are some functions to remove web-links from the tweets. We will also remove retweets and mentions. We remove these because it is unlikely that they will help us form meaningful topics.
#
# **We would like to know the general things which people are talking about, not who they are talking about or to and not the web links they are sharing.**
#
#
# Next, we stem the words in the list. This is essentially where we knock the end off the words. We do this so that similar words will be recognised as the same word by the algorithm

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
lemma = nltk.wordnet.WordNetLemmatizer()
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@.""-,`'
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

# cleaning master function
def clean_tweet(tweet, bigrams=True):
    p = TwitterPreprocessor(tweet)
    # preprocess test
    p.fully_preprocess()
    tweet = p.text
    return tweet

# %%
tweets['clean_tweet'] = tweets.full_text.apply(clean_tweet)

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                            full_text  is_retweet retweeted  \
# 0  I have taken it up with @fccpcnigeria . Hopefu...       False        []
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawaha...       False        []
# 2  @ChickenRepublic Dear @fccpcnigeria kindly advise       False        []
# 3  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
# 4  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
#
#                                            mentioned hashtags  \
# 0                 ['@fccpcnigeria', '@fccpcnigeria']       []
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG',...       []
# 2              ['@ChickenRepublic', '@fccpcnigeria']       []
# 3  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
# 4  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
#
#                                          clean_tweet
# 0  taken hopefully resolved nobody protects consu...
# 1  people lucky theyve taken transformer office p...
# 2                                 dear kindly advise
# 3
# 4

# %%
def lemmatization(tweet, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    doc = nlp(" ".join(tweet)) 
    texts_out = " ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags])
        
    return texts_out

def tweet_to_words(tweet):
    yield(gensim.utils.simple_preprocess(str(tweet), deacc=True))  # deacc=True removes punctuations

# %%
tweets['tokenized_tweet'] = tweets.clean_tweet.apply(tweet_to_words)

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                            full_text  is_retweet retweeted  \
# 0  I have taken it up with @fccpcnigeria . Hopefu...       False        []
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawaha...       False        []
# 2  @ChickenRepublic Dear @fccpcnigeria kindly advise       False        []
# 3  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
# 4  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
#
#                                            mentioned hashtags  \
# 0                 ['@fccpcnigeria', '@fccpcnigeria']       []
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG',...       []
# 2              ['@ChickenRepublic', '@fccpcnigeria']       []
# 3  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
# 4  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
#
#                                          clean_tweet  \
# 0  taken hopefully resolved nobody protects consu...
# 1  people lucky theyve taken transformer office p...
# 2                                 dear kindly advise
# 3
# 4
#
#                                     tokenized_tweet
# 0  <generator object tweet_to_words at 0x128c5d850>
# 1  <generator object tweet_to_words at 0x128c5d450>
# 2  <generator object tweet_to_words at 0x128c5d8d0>
# 3  <generator object tweet_to_words at 0x128c5d950>
# 4  <generator object tweet_to_words at 0x128c5d9d0>

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# Run in terminal: python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only Noun, Adj, Verb, Adverb
tweets['lemmatized_tweet'] = tweets.clean_tweet.apply(lemmatization)

# %%
tweets.head()

# %%
pd.options.display.max_colwidth = 200

# %%
tweets.clean_tweet.unique().size
# Out:
# 146761

# %% [markdown]
# #### Applying LDA
#
# Now that we have clean text we can apply some processing to turn the clean tweets into vectors and then build a model.
#
# To turn the text into a matrix*, where each row in the matrix encodes which words appeared in each individual tweet.
#
#
# We will also filter the words `max_df=0.9` means we discard any words that appear in >90% of tweets. In this dataset I don’t think there are any words that are that common but it is good practice. We will also filter words using `min_df=25`, so words that appear in less than 25 tweets will be discarded. We discard high appearing words since they are too common to be meaningful in topics. We discard low appearing words because we won’t have a strong enough signal and they will just introduce noise to our model.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=250, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(tweets['clean_tweet']) #.toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

# %%
tf.shape
# Out:
# (200000, 1267)

# %%
tf_feature_names
# Out:
# ['abeg',
#  'abi',
#  'able',
#  'abuja',
#  'acc',
#  'access',
#  'accessbank',
#  'account',
#  'accountbank',
#  'accountcredited',
#  'accountdebited',
#  'accountdetail',
#  'accountid',
#  'accountnumber',
#  'accountplease',
#  'accountsince',
#  'accountusername',
#  'accountyet',
#  'acct',
#  'across',
#  'act',
#  'action',
#  'activate',
#  'activated',
#  'activategb',
#  'activatewawu',
#  'active',
#  'actually',
#  'add',
#  'address',
#  'adm',
#  'admin',
#  'adminpaicipate',
#  'advise',
#  'africa',
#  'african',
#  'afternoon',
#  'agency',
#  'agent',
#  'ago',
#  'ah',
#  'aide',
#  'aiel',
#  'aiime',
#  'aint',
#  'air',
#  'ale',
#  'alex',
#  'allow',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'always',
#  'ambassador',
#  'ame',
#  'among',
#  'amount',
#  'amp',
#  'annoying',
#  'another',
#  'answer',
#  'anymore',
#  'anyone',
#  'anything',
#  'apc',
#  'apologize',
#  'apologizeinconvenience',
#  'apology',
#  'app',
#  'appreciate',
#  'appropriately',
#  'area',
#  'arena',
#  'arenagame',
#  'around',
#  'arsenal',
#  'asap',
#  'ask',
#  'asked',
#  'asking',
#  'assist',
#  'assistance',
#  'assured',
#  'ast',
#  'atm',
#  'attached',
#  'attend',
#  'attention',
#  'available',
#  'availablenow',
#  'availablesale',
#  'avala',
#  'aware',
#  'away',
#  'b',
#  'ba',
#  'baba',
#  'babatunde',
#  'babatundeirukera',
#  'baby',
#  'bac',
#  'back',
#  'bad',
#  'balance',
#  'bank',
#  'bankaccount',
#  'banking',
#  'barcelona',
#  'based',
#  'bbn',
#  'bbnaija',
#  'bear',
#  'beat',
#  'become',
#  'becoming',
#  'beg',
#  'begging',
#  'believe',
#  'best',
#  'bet',
#  'betaccount',
#  'betbet',
#  'betid',
#  'betja',
#  'betjaaccount',
#  'betjaacct',
#  'betjabetking',
#  'betjabig',
#  'betjabooking',
#  'betjacap',
#  'betjacode',
#  'betjacoin',
#  'betjaodds',
#  'betjashop',
#  'betjaslip',
#  'betjaticket',
#  'betjatwitter',
#  'betjauser',
#  'betjawgb',
#  'betking',
#  'betmerrybet',
#  'better',
#  'betting',
#  'big',
#  'bigbetja',
#  'bigbrother',
#  'biggie',
#  'bihday',
#  'biko',
#  'bill',
#  'billing',
#  'bisola',
#  'bless',
#  'body',
#  'bonus',
#  'book',
#  'booking',
#  'bookingcode',
#  'boom',
#  'boring',
#  'bos',
#  'bought',
#  'boy',
#  'branch',
#  'brand',
#  'bring',
#  'bringing',
#  'bro',
#  'brother',
#  'brothernaija',
#  'brought',
#  'bubu',
#  'buhar',
#  'buhari',
#  'bundle',
#  'business',
#  'buy',
#  'buyfixed',
#  'c',
#  'ca',
#  'call',
#  'calladm',
#  'calladmin',
#  'called',
#  'calling',
#  'callwhatsapp',
#  'came',
#  'cant',
#  'cantwait',
#  'cap',
#  'card',
#  'care',
#  'carry',
#  'case',
#  'cash',
#  'cause',
#  'caused',
#  'cc',
#  'ce',
#  'ceec',
#  'ceo',
#  'challenge',
#  'chance',
#  'change',
#  'changed',
#  'channel',
#  'charge',
#  'charged',
#  'chat',
#  'check',
#  'checkdm',
#  'chelsea',
#  'child',
#  'choice',
#  'choose',
#  'chop',
#  'cindy',
#  'citizen',
#  'city',
#  'claim',
#  'clear',
#  'click',
#  'close',
#  'club',
#  'co',
#  'code',
#  'codeplease',
#  'codepls',
#  'coin',
#  'collect',
#  'come',
#  'coming',
#  'cominginbox',
#  'comment',
#  'commission',
#  'community',
#  'company',
#  'competition',
#  'complain',
#  'complained',
#  'complaining',
#  'complaint',
#  'complete',
#  'con',
#  'concern',
#  'confirm',
#  'congrats',
#  'congratulation',
#  'consumer',
#  'consumerprotection',
#  'contact',
#  'contacting',
#  'continue',
#  'cool',
#  'copy',
#  'correct',
#  'correctscore',
#  'cost',
#  'cou',
#  'could',
#  'couldnt',
#  'council',
#  'country',
#  'course',
#  'cpc',
#  'crazy',
#  'credit',
#  'creditaccount',
#  'credited',
#  'creditedaccount',
#  'creditedbetja',
#  'cry',
#  'cteam',
#  'cup',
#  'current',
#  'currently',
#  'customer',
#  'customercare',
#  'customerservice',
#  'cut',
#  'da',
#  'daily',
#  'darkness',
#  'dat',
#  'data',
#  'dataplan',
#  'date',
#  'day',
#  'de',
#  'deal',
#  'dear',
#  'debit',
#  'debitale',
#  'debited',
#  'debitedbank',
#  'december',
#  'decided',
#  'deducted',
#  'dee',
#  'definitely',
#  'delay',
#  'dem',
#  'deposit',
#  'depositaccount',
#  'deposited',
#  'deserve',
#  'despite',
#  'detail',
#  'device',
#  'dey',
#  'dg',
#  'diane',
#  'didnt',
#  'die',
#  'different',
#  'difficult',
#  'dis',
#  'disco',
#  'dly',
#  'dm',
#  'doesnt',
#  'done',
#  'dont',
#  'dontknow',
#  'dontunderstand',
#  'dontwant',
#  'double',
#  'doubt',
#  'drama',
#  'draw',
#  'drop',
#  'dstv',
#  'due',
#  'e',
#  'earlier',
#  'early',
#  'easy',
#  'ecoba',
#  'ecobank',
#  'eed',
#  'either',
#  'el',
#  'election',
#  'electricity',
#  'else',
#  'email',
#  'emailaddress',
#  'en',
#  'enable',
#  'enableu',
#  'end',
#  'endtoday',
#  'energy',
#  'enjoy',
#  'enough',
#  'ensure',
#  'enter',
#  'error',
#  'especially',
#  'estate',
#  'esther',
#  'estimated',
#  'estimatedbill',
#  'et',
#  'etc',
#  'even',
#  'evening',
#  'event',
#  'ever',
#  'every',
#  'everyday',
#  'everyone',
#  'everything',
#  'everywhere',
#  'evicted',
#  'eviction',
#  'ew',
#  'ewpost',
#  'exactly',
#  'expect',
#  'experience',
#  'explain',
#  'eye',
#  'face',
#  'fact',
#  'failed',
#  'failedtransaction',
#  'fair',
#  'fake',
#  'family',
#  'fan',
#  'far',
#  'fast',
#  'fault',
#  'fc',
#  'fccpc',
#  'federal',
#  'fee',
#  'feedback',
#  'feel',
#  'feeling',
#  'fight',
#  'final',
#  'finally',
#  'financial',
#  'find',
#  'fine',
#  'finish',
#  'fire',
#  'first',
#  'firstbank',
#  'fit',
#  'fix',
#  'fixed',
#  'fixedgame',
#  'fixedmatch',
#  'flight',
#  'follow',
#  'following',
#  'food',
#  'football',
#  'force',
#  'forever',
#  'forget',
#  'form',
#  'forward',
#  'found',
#  'four',
#  'fraud',
#  'fraudulent',
#  'free',
#  'friday',
#  'friend',
#  'frodd',
#  'frozen',
#  'fuher',
#  'full',
#  'fun',
#  'fund',
#  'fundaccount',
#  'fundbetja',
#  'funded',
#  'funding',
#  'funny',
#  'future',
#  'g',
#  'game',
#  'gameavailable',
#  'gamebetja',
#  'gameodds',
#  'gamestill',
#  'gamesuccessful',
#  'gave',
#  'gb',
#  'gbplan',
#  'gbwawu',
#  'gedoni',
#  'geria',
#  'get',
#  'getting',
#  'gig',
#  'girl',
#  'give',
#  'given',
#  'giveu',
#  'giving',
#  'glad',
#  'go',
#  'goal',
#  'god',
#  'godbless',
#  'going',
#  'gon',
#  'gone',
#  'gonna',
#  'good',
#  'goodday',
#  'goodevening',
#  'goodmorning',
#  'got',
#  'gotten',
#  'gotv',
#  'government',
#  'governor',
#  'govt',
#  'grab',
#  'graboppounity',
#  'great',
#  'green',
#  'group',
#  'grouptomorrow',
#  'gtb',
#  'gtbank',
#  'guaranteed',
#  'guaranteedgame',
#  'guess',
#  'guy',
#  'half',
#  'hand',
#  'handle',
#  'happen',
#  'happened',
#  'happening',
#  'happy',
#  'happybihday',
#  'hard',
#  'hasnt',
#  'hate',
#  'havent',
#  'he',
#  'hea',
#  'head',
#  'hear',
#  'heard',
#  'hello',
#  'hellokindly',
#  'helloplease',
#  'hellothank',
#  'help',
#  'helpactivate',
#  'helpu',
#  'hi',
#  'high',
#  'history',
#  'hm',
#  'hoh',
#  'hold',
#  'home',
#  'hope',
#  'hot',
#  'hour',
#  'house',
#  'housemate',
#  'however',
#  'hr',
#  'human',
#  'id',
#  'idusername',
#  'ike',
#  'ill',
#  'im',
#  'imagine',
#  'immediately',
#  'inbox',
#  'inboxwhatsapp',
#  'inconvenience',
#  'info',
#  'information',
#  'informed',
#  'inside',
#  'instead',
#  'interest',
#  'interested',
#  'internet',
#  'irukera',
#  'isnt',
#  'issue',
#  'issueresolved',
#  'ive',
#  'ja',
#  'jacket',
#  'jackye',
#  'jeff',
#  'jersey',
#  'job',
#  'join',
#  'june',
#  'k',
#  'keep',
#  'kept',
#  'khafi',
#  'kill',
#  'kinbox',
#  'kind',
#  'kindly',
#  'kindlyactivate',
#  'kindlyassist',
#  'kindlyforward',
#  'kindlyhelp',
#  'kindlyinformed',
#  'kindlyprovide',
#  'king',
#  'know',
#  'kogi',
#  'kuchikau',
#  'la',
#  'lady',
#  'lagos',
#  'last',
#  'lastnight',
#  'lastweek',
#  'lastyear',
#  'late',
#  'later',
#  'law',
#  'le',
#  'leader',
#  'league',
#  'learn',
#  'least',
#  'leave',
#  'left',
#  'let',
#  'letter',
#  'level',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'likebetja',
#  'line',
#  'link',
#  'list',
#  'little',
#  'live',
#  'liverpool',
#  'lo',
#  'load',
#  'local',
#  'location',
#  'log',
#  'login',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'los',
#  'lose',
#  'loss',
#  'lost',
#  'lot',
#  'love',
#  'low',
#  'lucky',
#  'mad',
#  'made',
#  'madedeposit',
#  'madepayment',
#  'madewithdrawal',
#  'mail',
#  'main',
#  'make',
#  'making',
#  'man',
#  'manchester',
#  'mancity',
#  'many',
#  'manybuy',
#  'mao',
#  'march',
#  'market',
#  'match',
#  'matchtoday',
#  'mate',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'medium',
#  'meet',
#  'meeting',
#  'member',
#  'men',
#  'mercy',
#  'merrybet',
#  'merrybetmany',
#  'mess',
#  'message',
#  'messageplatform',
#  'meter',
#  'mi',
#  'might',
#  'mike',
#  'million',
#  'min',
#  'mind',
#  'mine',
#  'minute',
#  'miracle',
#  'miss',
#  'missed',
#  'missing',
#  'mistake',
#  'mobile',
#  'mobileapp',
#  'moment',
#  'monday',
#  'money',
#  'moneyaccount',
#  'moneybetja',
#  'month',
#  'monthly',
#  'morning',
#  'move',
#  'mr',
#  'much',
#  'must',
#  'n',
#  'na',
#  'nah',
#  'naija',
#  'naira',
#  'nairabet',
#  'nairabetwazobia',
#  'name',
#  'nation',
#  'national',
#  'nd',
#  'need',
#  'needed',
#  'needhelp',
#  'needmoney',
#  'network',
#  'never',
#  'new',
#  'news',
#  'next',
#  'ni',
#  'nice',
#  'nigeria',
#  'nigerian',
#  'night',
#  'nobody',
#  'nonsense',
#  'note',
#  'nothing',
#  'nothingdone',
#  'notice',
#  'november',
#  'now',
#  'ntel',
#  'number',
#  'october',
#  'odd',
#  'odds',
#  'oddsbetja',
#  'oddsprice',
#  'offer',
#  'office',
#  'official',
#  'oga',
#  'oh',
#  'ok',
#  'okay',
#  'ol',
#  'old',
#  'omashola',
#  'one',
#  'online',
#  'oo',
#  'ooo',
#  'oooo',
#  'open',
#  'oppounity',
#  'oppounitywinning',
#  'option',
#  'order',
#  'orite',
#  'osinbajo',
#  'others',
#  'ourite',
#  'outage',
#  'outside',
#  'ove',
#  'ow',
#  'pa',
#  'package',
#  'page',
#  'paicipate',
#  'paid',
#  'pain',
#  'pas',
#  'password',
#  'past',
#  'patience',
#  'patient',
#  'pay',
#  'paying',
#  'payment',
#  'pending',
#  'people',
#  'pepper',
#  'per',
#  'person',
#  'phone',
#  'phonenumber',
#  'photo',
#  'pick',
#  'picture',
#  'place',
#  'placebet',
#  'placed',
#  'plan',
#  'platform',
#  'platformbetja',
#  'play',
#  'playbetja',
#  'played',
#  'player',
#  'playgame',
#  'playing',
#  'playingbetja',
#  'please',
#  'pleaseactivate',
#  'pleasecheck',
#  'pleasehelp',
#  'pleasekindly',
#  'pleaseneed',
#  'pleasewant',
#  'pls',
#  'plshelp',
#  'plskindly',
#  'plsneed',
#  'plus',
#  'plz',
#  'pm',
#  'po',
#  'point',
#  'polaris',
#  'polarisba',
#  'polarisbank',
#  'police',
#  'policy',
#  'poor',
#  'por',
#  'possible',
#  'post',
#  'power',
#  'powersupply',
#  'pray',
#  'prediction',
#  'prepaid',
#  'prepaidmeter',
#  'presidency',
#  'president',
#  'presidentbuhari',
#  'price',
#  'pricek',
#  'problem',
#  'process',
#  'product',
#  'promise',
#  'promised',
#  'protection',
#  'protectioncouncil',
#  'proud',
#  'proudly',
#  'provide',
#  'provided',
#  'public',
#  'purchase',
#  'put',
#  'que',
#  'queen',
#  'question',
#  'quick',
#  'rather',
#  'rd',
#  'reach',
#  'read',
#  'ready',
#  'real',
#  'really',
#  'reason',
#  'receive',
#  'received',
#  'recharge',
#  'record',
#  'rectify',
#  'red',
#  'reflect',
#  'reflected',
#  'reflecting',
#  'refund',
#  'refunded',
#  'refundmoney',
#  'refuse',
#  'refused',
#  'regard',
#  'regardbetja',
#  'regarding',
#  'register',
#  'registered',
#  'regret',
#  'relationship',
#  'release',
#  'remain',
#  'remember',
#  'remove',
#  'reply',
#  'repo',
#  'repoed',
#  'request',
#  'requested',
#  'reset',
#  'resolution',
#  'resolve',
#  'resolved',
#  'respect',
#  'respond',
#  'responding',
#  'response',
#  'rest',
#  'restore',
#  'restored',
#  'result',
#  'return',
#  'retweet',
#  'reversal',
#  'reverse',
#  'reversed',
#  'review',
#  'reward',
#  'rice',
#  'right',
#  'risk',
#  'road',
#  'ronaldo',
#  'room',
#  'rubbish',
#  'rule',
#  'run',
#  'running',
#  'sa',
#  'sack',
#  'sad',
#  'safe',
#  'said',
#  'sale',
#  'saleodds',
#  'saturday',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'scam',
#  'scammer',
#  'school',
#  'score',
#  'screen',
#  'screenshot',
#  'se',
#  'season',
#  'second',
#  'see',
#  'seeing',
#  'seems',
#  'seen',
#  'sef',
#  'self',
#  'senate',
#  'senatethreatens',
#  'send',
#  'sending',
#  'sendu',
#  'sense',
#  'sent',
#  'serious',
#  'seriously',
#  'service',
#  'session',
#  'set',
#  'several',
#  'sey',
#  'seyi',
#  'sha',
#  'shall',
#  'shame',
#  'share',
#  'sharetestimony',
#  'shes',
#  'shit',
#  'sho',
#  'shop',
#  'shouldnt',
#  'show',
#  'showing',
#  'shut',
#  'shutdown',
#  'shutdownbetja',
#  'si',
#  'side',
#  'sign',
#  'sim',
#  'simple',
#  'simply',
#  'since',
#  'sincelast',
#  'sincerely',
#  'sincerelyapologize',
#  'sinceyesterday',
#  'single',
#  'sir',
#  'sirdee',
#  'site',
#  'situation',
#  'sleep',
#  'slip',
#  ...]

# %% [markdown]
# The tf matrix is similar to the hashtag_vector_df dataframe. Each row is a tweet and each column is a word. The numbers in each position tell us how many times this word appears in this tweet.
#
# Next we create the model object. Lets start by randomly choosing 10 topics.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=45) # random state for reproducibility

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=45, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# Next we will inspect our topics that we generated and try to extract meaningful information from them.

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0        bet9ja         26732.8         power          2796.5       bbnaija
# 1          code          4500.0           one          2375.0            na
# 2          play          3591.0         still          1945.0         mercy
# 3          game          3491.8          game          1568.6          wawu
# 4          odds          2642.4           pay          1563.9      activate
# 5           win          2341.9           yes          1526.3           dey
# 6           bet          1950.2          last          1410.4            go
# 7        ticket          1655.2        coming          1390.5           ike
# 8        please          1576.0           day          1385.4         tacha
# 9           pls          1558.2         light          1307.1         house
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0          4653.8        please          7545.2       nigeria         11614.2
# 1          3782.7         money          3624.9           the          4356.0
# 2          3149.9          help          3142.6        buhari          4245.8
# 3          2822.1         since          3079.8          dont          3713.2
# 4          2754.4        kindly          2438.7          know          3655.7
# 5          2665.7         issue          1936.8          like          3149.0
# 6          2502.3           yet          1887.3        people          2979.9
# 7          2442.4            cc          1695.7           you          2627.5
# 8          2329.9      response          1617.5           one          1837.1
# 9          2085.4          good          1585.2           amp          1809.0
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0             ’         11781.5            us          4978.3       account
# 1           see          2890.2         thank          4316.1        bet9ja
# 2          what          2588.3        kindly          4076.0            id
# 3          time          2295.7         hello          3408.8        please
# 4            it          2262.1            we          3009.4      credited
# 5         money          1726.6            dm          2960.9          bank
# 6          even          1703.8        please          2896.8      username
# 7        people          1558.4        number          2645.8         money
# 8          they          1499.4          team          2240.4           pls
# 9           you          1474.7     complaint          1934.2           bet
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0         17494.9          bank          6303.2        bet9ja          8210.5
# 1          6743.6       polaris          3541.1       bbnaija          4921.9
# 2          4507.0          call          2707.2           win          3004.7
# 3          4061.0        bet365          2541.1           big          2700.1
# 4          3411.5       ecobank          2230.1          bubu          2564.2
# 5          3379.7          bwin          2179.1             😂          2424.9
# 6          2906.1          just          2042.3       winning          2227.3
# 7          2771.4   williamhill          1999.1            de          2218.1
# 8          2672.4        bet9ja          1893.6         games          1861.0
# 9          2670.3      whatsapp          1785.4       brother          1809.1

# %% [markdown]
# ### Non-negative Matrix Factorisation (NMF).

# %%
from sklearn.decomposition import NMF

# %%
model_nmf = NMF(n_components=number_of_topics, random_state=42, alpha=.1, l1_ratio=.5, verbose=True)

# %%
model_nmf.fit(tf)
# Out:
# violation: 1.0
# violation: 0.3021239366955817
# violation: 0.19072065088007276
# violation: 0.08587871308382568
# violation: 0.03927028734613173
# violation: 0.021774903955333665
# violation: 0.013004158187007883
# violation: 0.008266471839519807
# violation: 0.0059314822937103695
# violation: 0.004782416037180024
# violation: 0.00418750562293099
# violation: 0.00388801740057672
# violation: 0.003749348712213601
# violation: 0.0036777117088381325
# violation: 0.0036291640214035975
# violation: 0.0035926761485269416
# violation: 0.003563656294413012
# violation: 0.0035398232790722134
# violation: 0.0035196295938652116
# violation: 0.003502161702992927
# violation: 0.0034868221976557577
# violation: 0.003473123830455181
# violation: 0.003460716102122241
# violation: 0.003449322185886566
# violation: 0.0034387118953286165
# violation: 0.0034287209992343
# violation: 0.003419201086678527
# violation: 0.00341005836283664
# violation: 0.0034012178895608744
# violation: 0.0033926197854820214
# violation: 0.003384216282293012
# violation: 0.003375964856613285
# violation: 0.0033678247792474267
# violation: 0.0033597782821298957
# violation: 0.0033517981472858016
# violation: 0.0033438769881803123
# violation: 0.003336003792841108
# violation: 0.0033281601516427007
# violation: 0.003320345307509709
# violation: 0.0033125517783116273
# violation: 0.0033047911025420665
# violation: 0.0032970346660109178
# violation: 0.003289280736415652
# violation: 0.0032815342745983133
# violation: 0.0032737930226586142
# violation: 0.0032660536959270973
# violation: 0.003258316358468094
# violation: 0.0032505783748048834
# violation: 0.003242840533366984
# violation: 0.0032351030704542453
# violation: 0.003227361913431046
# violation: 0.0032196179076463666
# violation: 0.0032118765445781645
# violation: 0.0032041275784288593
# violation: 0.0031963782522212805
# violation: 0.0031886241769759176
# violation: 0.0031808663387968795
# violation: 0.003173103311983269
# violation: 0.0031653357545503827
# violation: 0.003157563302398966
# violation: 0.003149787474830424
# violation: 0.0031420067636155086
# violation: 0.003134221600566951
# violation: 0.003126432232426783
# violation: 0.0031186429929875295
# violation: 0.0031108468720429444
# violation: 0.0031030471481722126
# violation: 0.0030952422840111534
# violation: 0.003087434764386974
# violation: 0.003079621143015465
# violation: 0.003071803004994629
# violation: 0.0030639846764251685
# violation: 0.0030561617096929424
# violation: 0.003048332914911798
# violation: 0.003040500599663322
# violation: 0.0030326637356532246
# violation: 0.0030248239991631353
# violation: 0.003016982381836894
# violation: 0.003009137825827836
# violation: 0.0030012878590551595
# violation: 0.00299343361752225
# violation: 0.0029855759410981828
# violation: 0.0029777152015569796
# violation: 0.002969854212588694
# violation: 0.002961989549749189
# violation: 0.002954120273981
# violation: 0.002946249012482174
# violation: 0.0029383764843916205
# violation: 0.002930501834597385
# violation: 0.0029226304339171187
# violation: 0.002914749492268523
# violation: 0.0029068683844892655
# violation: 0.002898985642557654
# violation: 0.002891101865922162
# violation: 0.002883214789682731
# violation: 0.0028753258095718377
# violation: 0.0028674361747437413
# violation: 0.0028595467382353254
# violation: 0.00285165632638191
# violation: 0.002843764583188035
# violation: 0.002835871707248289
# violation: 0.0028279787510893883
# violation: 0.0028200856529219383
# violation: 0.002812192531115519
# violation: 0.002804300020253057
# violation: 0.002796407071373383
# violation: 0.0027885155175861034
# violation: 0.002780624436439485
# violation: 0.0027727353658080593
# violation: 0.002764847477771289
# violation: 0.0027569599684874437
# violation: 0.0027490740556797323
# violation: 0.0027411906074580644
# violation: 0.002733309183947059
# violation: 0.002725429284331722
# violation: 0.0027175513739643303
# violation: 0.0027096760786110567
# violation: 0.002701805443245571
# violation: 0.0026939360166157705
# violation: 0.0026860691234491104
# violation: 0.0026782046476574524
# violation: 0.0026703444217740253
# violation: 0.00266248780082412
# violation: 0.002654636689614215
# violation: 0.0026467874067490106
# violation: 0.0026389433252637516
# violation: 0.0026311027354241987
# violation: 0.002623277097653545
# violation: 0.0026154492945373036
# violation: 0.0026076239642773766
# violation: 0.002599801872944824
# violation: 0.0025919860169480472
# violation: 0.002584175613544281
# violation: 0.0025763698178790408
# violation: 0.0025685707726508297
# violation: 0.0025607774667695195
# violation: 0.0025529898359633045
# violation: 0.0025452089711444715
# violation: 0.0025374364638349315
# violation: 0.002529669197506694
# violation: 0.0025219094124411204
# violation: 0.0025141573304402498
# violation: 0.0025064113223427537
# violation: 0.0024986731477548217
# violation: 0.0024909421814208114
# violation: 0.0024832195789687
# violation: 0.0024755052965869315
# violation: 0.002467798794115931
# violation: 0.002460101266395661
# violation: 0.0024524121557798237
# violation: 0.002444733704634743
# violation: 0.0024370635096065208
# violation: 0.002429401605449601
# violation: 0.002421748845822498
# violation: 0.002414104997950044
# violation: 0.0024064715986841113
# violation: 0.002398847374097615
# violation: 0.002391232325457025
# violation: 0.0023836282519298854
# violation: 0.0023760365285896675
# violation: 0.002368457802812868
# violation: 0.002360886792384737
# violation: 0.0023533259910921314
# violation: 0.0023457761767918866
# violation: 0.002338236271146196
# violation: 0.0023307078971479722
# violation: 0.0023231916018673963
# violation: 0.0023156871368794703
# violation: 0.0023081937966269376
# violation: 0.002300712200374954
# violation: 0.0022932432511545225
# violation: 0.002285787428065644
# violation: 0.0022783424991370833
# violation: 0.002270910350450513
# violation: 0.00226349154282646
# violation: 0.002256085396725861
# violation: 0.002248691948860312
# violation: 0.002241310967217197
# violation: 0.0022339436785740042
# violation: 0.002226594888488069
# violation: 0.0022192546271554057
# violation: 0.0022119276096762455
# violation: 0.0022046148175130604
# violation: 0.0021973156084507833
# violation: 0.002190029934386592
# violation: 0.0021827615275930956
# violation: 0.002175505257289476
# violation: 0.002168262679463222
# violation: 0.0021610349144416713
# violation: 0.0021538212290405133
# violation: 0.00214662170023246
# violation: 0.0021394372782568764
# violation: 0.002132267832413547
# violation: 0.002125113398517506
# violation: 0.0021179742328908176
# violation: 0.002110850558841072
# violation: 0.0021037422719260607
# violation: 0.002096649283967231
# violation: 0.002089571920623294
# violation: 0.0020825106069114734
# NMF(alpha=0.1, beta_loss='frobenius', init=None, l1_ratio=0.5, max_iter=200,
#     n_components=10, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=True)

# %%
no_top_words = 10
nmf_topics = display_topics(model_nmf, tf_feature_names, no_top_words)

# %%
nmf_topics.head(20)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0             ’            21.8       account            18.3         betja
# 1        buhari             1.2  betjaaccount             3.6          code
# 2             ‘             0.8            id             2.8          coin
# 3      osinbajo             0.6         money             2.6  betjaaccount
# 4             ”             0.5      credited             2.5     betjacode
# 5           let             0.4       debited             2.2     betjacoin
# 6             “             0.4      username             2.0          play
# 7          know             0.3   bankaccount             1.8     playbetja
# 8             –             0.3           pls             1.5          game
# 9       nigeria             0.3       deposit             1.5             –
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0            22.7           now             4.7        please            17.3
# 1             2.2           ✅✅✅             4.7          help             4.8
# 2             1.6         today             4.2    pleasehelp             2.6
# 3             1.5           bet             4.0          wawu             2.6
# 4             1.4         match             3.0      activate             2.5
# 5             1.3         fixed             3.0            gb             1.8
# 6             1.2       winning             2.9          plan             1.6
# 7             0.8    fixedmatch             2.8          line             1.5
# 8             0.7           big             2.7        thanks             1.4
# 9             0.6     oppounity             2.5        wawugb             1.2
#
#   Topic 5 words Topic 5 weights  Topic 6 words Topic 6 weights Topic 7 words  \
# 0          bank            15.3           game            10.5       nigeria
# 1       polaris             2.7       whatsapp             4.4         money
# 2   polarisbank             2.2           call             4.1           one
# 3         first             1.2          today             3.7          dont
# 4            ba             1.2          inbox             3.0           get
# 5        access             1.1      available             2.8        people
# 6     firstbank             1.0     guaranteed             2.7          like
# 7       ecobank             1.0           odds             2.7            go
# 8    accessbank             1.0   whatsappcall             2.6           day
# 9   bankaccount             0.9  inboxwhatsapp             2.5          know
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0             7.8             u            12.2           win             8.3
# 1             7.4        kindly             5.5          odds             6.8
# 2             5.9         hello             5.1    prediction             6.4
# 3             4.7     complaint             3.0           bet             5.5
# 4             4.7   hellokindly             2.6         daily             4.9
# 5             4.6          team             2.4          sure             3.7
# 6             4.5        enable             2.4             …             3.4
# 7             4.4       twitter             2.4       betting             3.2
# 8             4.1        regard             2.4           day             2.9
# 9             3.6         suppo             2.3        winbet             2.8
