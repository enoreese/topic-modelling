# %%
# packages to store and manipulate data
import pandas as pd
import numpy as np

# plotting packages
import matplotlib.pyplot as plt
import seaborn as sns

# model building package
import sklearn

# package to clean text
import re

# %%
tweets = pd.read_csv('data/tweets.csv', index_col=0)

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                            full_text  is_retweet retweeted  \
# 0  I have taken it up with @fccpcnigeria . Hopefu...       False        []
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawaha...       False        []
# 2  @ChickenRepublic Dear @fccpcnigeria kindly advise       False        []
# 3  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
# 4  @ChickenRepublic @CocaCola @CocaCola_NG @fccpc...       False        []
#
#                                            mentioned hashtags
# 0                 ['@fccpcnigeria', '@fccpcnigeria']       []
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG',...       []
# 2              ['@ChickenRepublic', '@fccpcnigeria']       []
# 3  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []
# 4  ['@ChickenRepublic', '@CocaCola', '@CocaCola_N...       []

# %%
tweets.shape
# Out:
# (200000, 6)

# %% [markdown]
# ## Topic Modelling
#
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. In our case, the collection of document is a collection or tweets.
#
# They are various algorithms used for topic modelling. Here we would look at **LDA** (Latent Dirichlet Allocation).
#
# LDA represents documents as mixtures of topics that spit out words with certain probabilities. It assumes that documents are produced in the following fashion: when writing each document, you
#
# - Decide on the number of words N the document will have (say, according to a Poisson distribution).
# - Choose a topic mixture for the document (according to a Dirichlet distribution over a fixed set of K topics). For example, assuming that we have the two food and cute animal topics above, you might choose the document to consist of 1/3 food and 2/3 cute animals.
# - Generate each word w_i in the document by:
#     - First picking a topic (according to the multinomial distribution that you sampled above; for example, you might pick the food topic with 1/3 probability and the cute animals topic with 2/3 probability).
#     - Using the topic to generate the word itself (according to the topic’s multinomial distribution). For example, if we selected the food topic, we might generate the word “broccoli” with 30% probability, “bananas” with 15% probability, and so on.
#
# **It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.**

# %% [markdown]
# ### Cleaning Unstructured Text Data
#
# The most important thing we need to do to help our topic modelling algorithm is to pre-clean up the tweets. Looking at the tweets you may notice that they are very untidy, with non-standard English, capitalisation, links, hashtags, @users and punctuation and emoticons everywhere. In order to properly apply topic modelling we need to remove most of this and massage our data into a more standard form before finally turning it into vectors.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %%
# download the stopwords if you have not used "nltk" before.
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/sasu/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Below are some functions to remove web-links from the tweets. We will also remove retweets and mentions. We remove these because it is unlikely that they will help us form meaningful topics.
#
# **We would like to know the general things which people are talking about, not who they are talking about or to and not the web links they are sharing.**
#
#
# Next, we stem the words in the list. This is essentially where we knock the end off the words. We do this so that similar words will be recognised as the same word by the algorithm

# %%
def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=True):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

# %%
tweets['clean_tweet'] = tweets.full_text.apply(clean_tweet)

# %%
pd.options.display.max_colwidth = 200

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                                                                                                                                                                                  full_text  \
# 0                               I have taken it up with @fccpcnigeria . Hopefully, it can be resolved. Nobody protects consumers in this country. Hopefully the revamped @fccpcnigeria can prove me wrong.
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawahalang @csm_ng @fccpcnigeria You people are lucky that they've taken your transformer to their office. As for the people of Ezenwagbara and Ndukuba Stre...
# 2                                                                                                                                                        @ChickenRepublic Dear @fccpcnigeria kindly advise
# 3                                                                                                                            @ChickenRepublic @CocaCola @CocaCola_NG @fccpcnigeria https://t.co/W8KYztwJhV
# 4                                                                                                                                                    @ChickenRepublic @CocaCola @CocaCola_NG @fccpcnigeria
#
#    is_retweet retweeted  \
# 0       False        []
# 1       False        []
# 2       False        []
# 3       False        []
# 4       False        []
#
#                                                                                      mentioned  \
# 0                                                           ['@fccpcnigeria', '@fccpcnigeria']
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG', '@nepawahalang', '@csm_ng', '@fccpcnigeria']
# 2                                                        ['@ChickenRepublic', '@fccpcnigeria']
# 3                           ['@ChickenRepublic', '@CocaCola', '@CocaCola_NG', '@fccpcnigeria']
# 4                           ['@ChickenRepublic', '@CocaCola', '@CocaCola_NG', '@fccpcnigeria']
#
#   hashtags  \
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#
#                                                                                                                                                                                                clean_tweet
# 0  taken hope resolv nobodi protect consum countri hope revamp prove wrong  taken_hope hope_resolv resolv_nobodi nobodi_protect protect_consum consum_countri countri_hope hope_revamp revamp_prove pro...
# 1   peopl lucki taken transform offic peopl ezenwagbara ndukuba street ariaria aba transform still sit tight stand  _peopl peopl_lucki lucki_taken taken_transform transform_offic offic_peopl peopl_ez...
# 2                                                                                                                                                         dear kindli advis _dear dear_kindli kindli_advis
# 3                                                                                                                                                                                                        _
# 4                                                                                                                                                                                                        _

# %%
tweets.head()
# Out:
#                        created_at  \
# 0  Sat Aug 24 05:28:19 +0000 2019
# 1  Sat Aug 24 05:22:35 +0000 2019
# 2  Fri Aug 09 18:01:30 +0000 2019
# 3  Fri Aug 09 17:48:03 +0000 2019
# 4  Fri Aug 09 17:47:12 +0000 2019
#
#                                                                                                                                                                                                  full_text  \
# 0                               I have taken it up with @fccpcnigeria . Hopefully, it can be resolved. Nobody protects consumers in this country. Hopefully the revamped @fccpcnigeria can prove me wrong.
# 1  @sanctitybona @enugudisco @PowerUpNG @nepawahalang @csm_ng @fccpcnigeria You people are lucky that they've taken your transformer to their office. As for the people of Ezenwagbara and Ndukuba Stre...
# 2                                                                                                                                                        @ChickenRepublic Dear @fccpcnigeria kindly advise
# 3                                                                                                                            @ChickenRepublic @CocaCola @CocaCola_NG @fccpcnigeria https://t.co/W8KYztwJhV
# 4                                                                                                                                                    @ChickenRepublic @CocaCola @CocaCola_NG @fccpcnigeria
#
#    is_retweet retweeted  \
# 0       False        []
# 1       False        []
# 2       False        []
# 3       False        []
# 4       False        []
#
#                                                                                      mentioned  \
# 0                                                           ['@fccpcnigeria', '@fccpcnigeria']
# 1  ['@sanctitybona', '@enugudisco', '@PowerUpNG', '@nepawahalang', '@csm_ng', '@fccpcnigeria']
# 2                                                        ['@ChickenRepublic', '@fccpcnigeria']
# 3                           ['@ChickenRepublic', '@CocaCola', '@CocaCola_NG', '@fccpcnigeria']
# 4                           ['@ChickenRepublic', '@CocaCola', '@CocaCola_NG', '@fccpcnigeria']
#
#   hashtags  \
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#
#                                                                                                                                                                                                clean_tweet
# 0  taken hope resolv nobodi protect consum countri hope revamp prove wrong  taken_hope hope_resolv resolv_nobodi nobodi_protect protect_consum consum_countri countri_hope hope_revamp revamp_prove pro...
# 1   peopl lucki taken transform offic peopl ezenwagbara ndukuba street ariaria aba transform still sit tight stand  _peopl peopl_lucki lucki_taken taken_transform transform_offic offic_peopl peopl_ez...
# 2                                                                                                                                                         dear kindli advis _dear dear_kindli kindli_advis
# 3                                                                                                                                                                                                        _
# 4                                                                                                                                                                                                        _

# %%
tweets.clean_tweet.unique().size
# Out:
# 154911

# %% [markdown]
# #### Applying LDA
#
# Now that we have clean text we can apply some processing to turn the clean tweets into vectors and then build a model.
#
# To turn the text into a matrix*, where each row in the matrix encodes which words appeared in each individual tweet.
#
#
# We will also filter the words `max_df=0.9` means we discard any words that appear in >90% of tweets. In this dataset I don’t think there are any words that are that common but it is good practice. We will also filter words using `min_df=25`, so words that appear in less than 25 tweets will be discarded. We discard high appearing words since they are too common to be meaningful in topics. We discard low appearing words because we won’t have a strong enough signal and they will just introduce noise to our model.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=250, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(tweets['clean_tweet']) #.toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

# %%
tf.shape
# Out:
# (200000, 1657)

# %%
tf_feature_names
# Out:
# ['#',
#  '#_',
#  '#apuestas',
#  '#bbnaija',
#  '#bbnaija_',
#  '#bbnaija_#bbnaija',
#  '#bbnaija_#betja',
#  '#bbnaijapepperdem',
#  '#bbnaijapepperdem_#tacha',
#  '#bbnaijia',
#  '#bbnajia',
#  '#bet',
#  '#bet_#bet',
#  '#bet_#betfair',
#  '#bet_#betja',
#  '#bet_#betting',
#  '#bet_#soccer',
#  '#bet_#williamhill',
#  '#betclic',
#  '#betfair',
#  '#betfair_#bet',
#  '#betin',
#  '#betja',
#  '#betja_',
#  '#betja_#bet',
#  '#betja_#nairabet',
#  '#betja_#sportpesa',
#  '#betja_#sportybet',
#  '#betja_#wgb',
#  '#betjabbn',
#  '#betjabbn_',
#  '#betjalive',
#  '#betking',
#  '#betpawa',
#  '#betting',
#  '#bettingexpert',
#  '#bettingtips',
#  '#betway',
#  '#bigbronaija',
#  '#bigbrothernaija',
#  '#bitcoin',
#  '#blackbet',
#  '#bovada',
#  '#bovada_#merrybet',
#  '#bovada_#nairabet',
#  '#bwin',
#  '#bwin_#bet',
#  '#bwin_#bovada',
#  '#completesports',
#  '#completesports_#soccer',
#  '#fixedmatch',
#  '#fixedmatches',
#  '#football',
#  '#inplay',
#  '#liverpool',
#  '#merrybet',
#  '#merrybet_#naira',
#  '#mfm',
#  '#mfm_#completesports',
#  '#money',
#  '#mufc',
#  '#naija',
#  '#naijabet',
#  '#naira',
#  '#naira_',
#  '#nairabet',
#  '#nairabet_#bet',
#  '#nairabet_#merrybet',
#  '#nff',
#  '#nff_#mfm',
#  '#nigeria',
#  '#paddypower',
#  '#pepperdem',
#  '#pepperdem_#bbnaijapepperdem',
#  '#scommesse',
#  '#soccer',
#  '#soccer_#soccer',
#  '#soccer_#williamhill',
#  '#sport',
#  '#sportpesa',
#  '#sportpesa_#bwin',
#  '#sportybet',
#  '#sportybet_',
#  '#surebet',
#  '#tacha',
#  '#tips',
#  '#unibet',
#  '#wgb',
#  '#wgb_#nairabet',
#  '#williamhill',
#  '#williamhill_#bwin',
#  '#williamhill_#nff',
#  '#winnersgoldenbet',
#  '#xbet',
#  '_',
#  '_abeg',
#  '_account',
#  '_also',
#  '_amp',
#  '_arsen',
#  '_b',
#  '_bank',
#  '_bet',
#  '_betja',
#  '_biggi',
#  '_bro',
#  '_bubu',
#  '_buhari',
#  '_c',
#  '_call',
#  '_check',
#  '_chelsea',
#  '_come',
#  '_congrat',
#  '_congratul',
#  '_correct',
#  '_credit',
#  '_day',
#  '_dear',
#  '_debit',
#  '_deposit',
#  '_done',
#  '_ecobank',
#  '_even',
#  '_first',
#  '_fix',
#  '_frodd',
#  '_fund',
#  '_game',
#  '_get',
#  '_give',
#  '_go',
#  '_god',
#  '_good',
#  '_got',
#  '_guarante',
#  '_guy',
#  '_happi',
#  '_hello',
#  '_help',
#  '_hi',
#  '_hope',
#  '_hour',
#  '_i',
#  '_ike',
#  '_issu',
#  '_it',
#  '_k',
#  '_kelechii',
#  '_kindli',
#  '_know',
#  '_let',
#  '_like',
#  '_liverpool',
#  '_lol',
#  '_look',
#  '_love',
#  '_made',
#  '_make',
#  '_man',
#  '_merci',
#  '_mike',
#  '_million',
#  '_miss',
#  '_money',
#  '_month',
#  '_na',
#  '_naira',
#  '_name',
#  '_need',
#  '_never',
#  '_nice',
#  '_nigeria',
#  '_odd',
#  '_oh',
#  '_ok',
#  '_okay',
#  '_omashola',
#  '_one',
#  '_peopl',
#  '_pl',
#  '_play',
#  '_pleas',
#  '_pm',
#  '_polari',
#  '_price',
#  '_realli',
#  '_say',
#  '_see',
#  '_send',
#  '_sent',
#  '_seyi',
#  '_show',
#  '_sinc',
#  '_sir',
#  '_sorri',
#  '_spiriitu',
#  '_still',
#  '_sure',
#  '_tacha',
#  '_team',
#  '_tell',
#  '_thank',
#  '_think',
#  '_time',
#  '_today',
#  '_tri',
#  '_true',
#  '_u',
#  '_use',
#  '_user',
#  '_usernam',
#  '_vote',
#  '_wait',
#  '_want',
#  '_week',
#  '_well',
#  '_win',
#  '_work',
#  '_would',
#  '_wow',
#  '_xbet',
#  '_ye',
#  '_year',
#  '_yet',
#  'abeg',
#  'abi',
#  'abl',
#  'abuja',
#  'acc',
#  'accept',
#  'access',
#  'access_bank',
#  'account',
#  'account_',
#  'account_bank',
#  'account_credit',
#  'account_debit',
#  'account_detail',
#  'account_id',
#  'account_number',
#  'account_pleas',
#  'account_sinc',
#  'account_usernam',
#  'account_yet',
#  'acct',
#  'acknowledg',
#  'across',
#  'act',
#  'action',
#  'activ',
#  'activ_',
#  'activ_gb',
#  'activ_line',
#  'activ_wawu',
#  'actual',
#  'ad',
#  'add',
#  'address',
#  'admin',
#  'admin_',
#  'admin_particip',
#  'advis',
#  'affect',
#  'afford',
#  'africa',
#  'african',
#  'afternoon',
#  'aga',
#  'agenc',
#  'agent',
#  'ago',
#  'agre',
#  'aid',
#  'air',
#  'airtel',
#  'airtim',
#  'alert',
#  'alex',
#  'allow',
#  'almost',
#  'alon',
#  'along',
#  'alreadi',
#  'also',
#  'alway',
#  'ambassador',
#  'among',
#  'amount',
#  'amount_',
#  'amp',
#  'amp_',
#  'announc',
#  'annoy',
#  'anoth',
#  'answer',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anyway',
#  'apc',
#  'apolog',
#  'apolog_delay',
#  'apolog_inconveni',
#  'app',
#  'appli',
#  'appreci',
#  'appropri',
#  'april',
#  'area',
#  'arena',
#  'arena_game',
#  'around',
#  'arsen',
#  'arsen_',
#  'asap',
#  'asap_',
#  'ask',
#  'assist',
#  'assist_',
#  'assur',
#  'atm',
#  'attach',
#  'attend',
#  'attent',
#  'avail',
#  'avail_now',
#  'avail_sale',
#  'avala',
#  'await',
#  'awar',
#  'away',
#  'b',
#  'ba',
#  'baba',
#  'babatund',
#  'babatund_irukera',
#  'babi',
#  'back',
#  'back_',
#  'bad',
#  'balanc',
#  'bank',
#  'bank_',
#  'bank_account',
#  'barcelona',
#  'base',
#  'bbn',
#  'bbnaija',
#  'bear',
#  'beat',
#  'beauti',
#  'becom',
#  'beg',
#  'begin',
#  'believ',
#  'best',
#  'bet',
#  'bet_',
#  'bet_account',
#  'bet_bet',
#  'bet_id',
#  'bet_merrybet',
#  'betja',
#  'betja_',
#  'betja_account',
#  'betja_acct',
#  'betja_betk',
#  'betja_big',
#  'betja_book',
#  'betja_cap',
#  'betja_code',
#  'betja_coin',
#  'betja_odd',
#  'betja_shop',
#  'betja_slip',
#  'betja_ticket',
#  'betja_twitter',
#  'betja_user',
#  'betja_wgb',
#  'betk',
#  'better',
#  'big',
#  'big_',
#  'big_brother',
#  'biggi',
#  'biko',
#  'bill',
#  'bill_',
#  'birthday',
#  'bisola',
#  'bless',
#  'block',
#  'bodi',
#  'bonu',
#  'book',
#  'book_code',
#  'book_number',
#  'boom',
#  'border',
#  'bore',
#  'boss',
#  'bought',
#  'boy',
#  'branch',
#  'brand',
#  'break',
#  'bring',
#  'bro',
#  'brother',
#  'brother_naija',
#  'brought',
#  'bubu',
#  'bubu_',
#  'buhari',
#  'buhari_',
#  'build',
#  'bundl',
#  'busi',
#  'buy',
#  'buy_fix',
#  'c',
#  'call',
#  'call_',
#  'call_admin',
#  'call_whatsapp',
#  'came',
#  'can',
#  'cancel',
#  'cannot',
#  'cant',
#  'cap',
#  'card',
#  'care',
#  'carri',
#  'case',
#  'cash',
#  'caus',
#  'cc',
#  'cc_',
#  'cee',
#  'ceec',
#  'celebr',
#  'ceo',
#  'challeng',
#  'chanc',
#  'chang',
#  'channel',
#  'channel_',
#  'charg',
#  'chat',
#  'check',
#  'check_dm',
#  'chelsea',
#  'chelsea_',
#  'choic',
#  'choos',
#  'chop',
#  'cindi',
#  'citi',
#  'citizen',
#  'claim',
#  'clear',
#  'click',
#  'close',
#  'club',
#  'co',
#  'code',
#  'code_',
#  'code_pl',
#  'code_pleas',
#  'coin',
#  'coin_',
#  'collect',
#  'com',
#  'come',
#  'come_',
#  'come_inbox',
#  'comment',
#  'commiss',
#  'commit',
#  'commun',
#  'compani',
#  'competit',
#  'complain',
#  'complaint',
#  'complaint_',
#  'complet',
#  'concern',
#  'confirm',
#  'congrat',
#  'congratul',
#  'connect',
#  'consum',
#  'consum_protect',
#  'contact',
#  'contact_us',
#  'continu',
#  'control',
#  'convert',
#  'cool',
#  'copi',
#  'correct',
#  'correct_score',
#  'corrupt',
#  'cost',
#  'could',
#  'council',
#  'count',
#  'countri',
#  'countri_',
#  'cours',
#  'court',
#  'cpc',
#  'crazi',
#  'creat',
#  'credit',
#  'credit_',
#  'credit_account',
#  'credit_betja',
#  'cri',
#  'cs',
#  'cs_team',
#  'cup',
#  'current',
#  'custom',
#  'custom_',
#  'custom_care',
#  'custom_servic',
#  'cut',
#  'da',
#  'daili',
#  'dark',
#  'dat',
#  'data',
#  'data_plan',
#  'date',
#  'day',
#  'day_',
#  'de',
#  'deal',
#  'dear',
#  'debit',
#  'debit_',
#  'debit_account',
#  'debit_alert',
#  'debit_bank',
#  'decemb',
#  'decid',
#  'deduct',
#  'dee',
#  'definit',
#  'delay',
#  'deliv',
#  'dem',
#  'demand',
#  'deposit',
#  'deposit_',
#  'deposit_account',
#  'deserv',
#  'despit',
#  'detail',
#  'detail_',
#  'develop',
#  'devic',
#  'dey',
#  'dg',
#  'di',
#  'dian',
#  'didn',
#  'die',
#  'differ',
#  'difficult',
#  'direct',
#  'disappoint',
#  'disco',
#  'disconnect',
#  'discuss',
#  'dm',
#  'dm_',
#  'doesn',
#  'don',
#  'done',
#  'done_',
#  'dont',
#  'doubl',
#  'doubt',
#  'drag',
#  'drama',
#  'draw',
#  'dream',
#  'drop',
#  'dstv',
#  'due',
#  'e',
#  'earli',
#  'earlier',
#  'earn',
#  'easi',
#  'ecobank',
#  'ecobank_',
#  'edit',
#  'educ',
#  'effect',
#  'effort',
#  'either',
#  'el',
#  'elect',
#  'electr',
#  'ella',
#  'els',
#  'email',
#  'email_address',
#  'emerg',
#  'en',
#  'enabl',
#  'enabl_us',
#  'end',
#  'end_today',
#  'energi',
#  'eng',
#  'engag',
#  'enjoy',
#  'enough',
#  'ensur',
#  'enter',
#  'error',
#  'es',
#  'especi',
#  'estat',
#  'esther',
#  'estim',
#  'estim_bill',
#  'etc',
#  'even',
#  'event',
#  'ever',
#  'everi',
#  'everyday',
#  'everyon',
#  'everyth',
#  'everywher',
#  'evict',
#  'evid',
#  'exactli',
#  'exist',
#  'expect',
#  'experi',
#  'experienc',
#  'expir',
#  'explain',
#  'eye',
#  'face',
#  'fact',
#  'fail',
#  'fail_transact',
#  'fair',
#  'fake',
#  'fall',
#  'famili',
#  'fan',
#  'far',
#  'fast',
#  'fault',
#  'favorit',
#  'favour',
#  'favourit',
#  'fc',
#  'fccpc',
#  'feder',
#  'fee',
#  'feedback',
#  'feel',
#  'fight',
#  'fill',
#  'final',
#  'financi',
#  'find',
#  'fine',
#  'finish',
#  'fire',
#  'first',
#  'first_bank',
#  'fit',
#  'fix',
#  'fix_game',
#  'fix_match',
#  'flight',
#  'follow',
#  'food',
#  'footbal',
#  'forc',
#  'forev',
#  'forget',
#  'form',
#  'forward',
#  'found',
#  'four',
#  'fraud',
#  'fraudul',
#  'free',
#  'friday',
#  'friend',
#  'frodd',
#  'frozen',
#  'frustrat',
#  'fuck',
#  'full',
#  'fun',
#  'fund',
#  'fund_account',
#  'fund_betja',
#  'funni',
#  'futur',
#  'g',
#  'gambl',
#  'game',
#  'game_',
#  'game_avail',
#  'game_betja',
#  'game_still',
#  'game_success',
#  'gave',
#  'gb',
#  'gb_',
#  'gb_plan',
#  'gb_wawu',
#  'gedoni',
#  'gener',
#  'get',
#  'get_',
#  'get_money',
#  'gig',
#  'girl',
#  'give',
#  'give_us',
#  'given',
#  'glad',
#  'go',
#  'go_',
#  'goal',
#  'god',
#  'god_bless',
#  'goe',
#  'gone',
#  'gonna',
#  'good',
#  'good_afternoon',
#  'good_day',
#  'good_even',
#  'good_morn',
#  'got',
#  'gotten',
#  'gotv',
#  'gov',
#  'govern',
#  'governor',
#  'govt',
#  'grab',
#  'grab_opportun',
#  'great',
#  'green',
#  'group',
#  'group_tomorrow',
#  'gt',
#  'gtb',
#  'guarante',
#  'guarante_game',
#  'guess',
#  'guy',
#  'guy_',
#  'half',
#  'hand',
#  'handl',
#  'happen',
#  'happen_',
#  'happi',
#  'happi_birthday',
#  'hard',
#  'hate',
#  'head',
#  'hear',
#  'heard',
#  'heart',
#  'hello',
#  'hello_kindli',
#  'hello_pleas',
#  'hello_sincer',
#  'hello_thank',
#  'help',
#  'help_',
#  'help_activ',
#  'help_us',
#  'hi',
#  'high',
#  'histori',
#  'hit',
#  'hm',
#  'hoh',
#  'hold',
#  'home',
#  'hope',
#  'hot',
#  'hour',
#  'hous',
#  'hous_',
#  'housem',
#  'howev',
#  'hr',
#  'human',
#  'i',
#  'id',
#  'id_',
#  'idea',
#  'ignor',
#  'ike',
#  'imagin',
#  'immedi',
#  'import',
#  'improv',
#  'inbox',
#  'inbox_whatsapp',
#  'includ',
#  'inconveni',
#  'indic',
#  'info',
#  'inform',
#  'initi',
#  'insid',
#  'instant',
#  'instead',
#  'insult',
#  'interest',
#  'interest_',
#  'intern',
#  'internet',
#  'invest',
#  'investig',
#  'invit',
#  'involv',
#  'irukera',
#  'issu',
#  'issu_',
#  'issu_resolv',
#  'it',
#  'ja',
#  'jacket',
#  'jacky',
#  'jeff',
#  'jersey',
#  'job',
#  'join',
#  'joke',
#  'june',
#  'k',
#  'k_',
#  'k_inbox',
#  'keep',
#  'kelechii',
#  'kelechii_betja',
#  'kept',
#  'khafi',
#  'kill',
#  'kim',
#  'kimoprah',
#  'kind',
#  'kindli',
#  'kindli_activ',
#  'kindli_assist',
#  'kindli_forward',
#  'kindli_help',
#  'kindli_inform',
#  'kindli_note',
#  'kindli_provid',
#  'kindli_repli',
#  'kindli_send',
#  'king',
#  'knew',
#  'know',
#  'know_',
#  'kogi',
#  'kuchikau',
#  'l',
#  'la',
#  'ladi',
#  'lago',
#  'last',
#  'last_night',
#  'last_week',
#  'last_year',
#  'late',
#  'later',
#  'law',
#  'le',
#  'lead',
#  'leader',
#  'leagu',
#  'learn',
#  'least',
#  'leav',
#  'left',
#  'less',
#  'let',
#  'let_us',
#  'letter',
#  'level',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'like_',
#  'like_betja',
#  'limit',
#  'line',
#  'line_',
#  'link',
#  'list',
#  'listen',
#  'littl',
#  'live',
#  'liverpool',
#  'liverpool_',
#  'lmao',
#  'lo',
#  'load',
#  'local',
#  'locat',
#  'lodg',
#  'log',
#  'login',
#  'lol',
#  'lol_',
#  'london',
#  'long',
#  'longer',
#  'look',
#  'look_like',
#  'loos',
#  'lose',
#  'loss',
#  'lost',
#  'lot',
#  'love',
#  'love_',
#  'low',
#  'luck',
#  'lucki',
#  'mad',
#  'made',
#  'made_deposit',
#  'made_payment',
#  'made_withdraw',
#  'mail',
#  'major',
#  'make',
#  'make_money',
#  'make_withdraw',
#  'man',
#  'man_citi',
#  'manag',
#  'manchest',
#  'mani',
#  'mani_buy',
#  'march',
#  'market',
#  'marri',
#  'match',
#  'match_',
#  'match_today',
#  'mate',
#  'matter',
#  'may',
#  'mayb',
#  'mean',
#  'media',
#  'meet',
#  'member',
#  'men',
#  'mention',
#  'merci',
#  'merci_',
#  'merrybet',
#  'merrybet_mani',
#  'mess',
#  'messag',
#  'messag_platform',
#  'messi',
#  'meter',
#  'mi',
#  'might',
#  'mike',
#  'million',
#  'min',
#  'mind',
#  'mine',
#  'minut',
#  'miracl',
#  'miss',
#  'mistak',
#  'mobil',
#  ...]

# %% [markdown]
# The tf matrix is similar to the hashtag_vector_df dataframe. Each row is a tweet and each column is a word. The numbers in each position tell us how many times this word appears in this tweet.
#
# Next we create the model object. Lets start by randomly choosing 10 topics.

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=45) # random state for reproducibility

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=45, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# Next we will inspect our topics that we generated and try to extract meaningful information from them.

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights  Topic 1 words Topic 1 weights Topic 2 words  \
# 0       nigeria          6304.4        account         18850.2         activ
# 1             i          3301.1          betja          6291.6             _
# 2           day          2901.4              #          6221.3          wawu
# 3      nigeria_          2263.4         credit          5357.8          plan
# 4           😂😂😂          2155.1          pleas          5246.4            de
# 5          bill          2120.9             ’t          4963.0            gb
# 6            cc          2046.3             pl          4709.8         pleas
# 7           pay          1866.3             id          4491.5          line
# 8           god          1859.7  betja_account          3900.1            la
# 9           cc_          1801.7           help          3721.3  #williamhill
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# 0          4045.3             u          6645.3        #betja          8288.5
# 1          3143.6          like          5529.9          bank          4781.4
# 2          2885.1           one          5150.3          game          4650.9
# 3          2547.0         peopl          4619.7         today          3897.1
# 4          2369.1       nigeria          4550.3        polari          3533.1
# 5          2151.1          know          4506.9           win          3265.9
# 6          1773.3             😂          4308.3          bubu          3143.8
# 7          1728.2            go          4088.5             _          3012.5
# 8          1583.1          make          3129.0          #bet          2914.5
# 9          1392.7          even          2992.2   polari_bank          2804.8
#
#   Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights Topic 7 words  \
# 0      #bbnaija         16929.1          play          5594.6         thank
# 1             ’         11119.1         betja          4425.4        kindli
# 2         betja          4003.6          game          2565.9         hello
# 3          coin          3896.9          wait          2135.7            us
# 4        buhari          3683.9       support          2127.2        _hello
# 5         merci          3232.9       twitter          1998.5        _thank
# 6            it          3108.1           see          1851.4        thank_
# 7         tacha          3013.5    play_betja          1762.1            dm
# 8          vote          2444.6         check          1599.9           via
# 9             –          2413.1        regard          1340.4         pleas
#
#   Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0          8874.5         pleas          7901.0             _         25667.5
# 1          4003.4         money          6612.0         betja         22370.7
# 2          3148.9          sinc          3845.3        _betja          5954.2
# 3          3051.2        _pleas          3599.5          code          4973.4
# 4          2846.4          need          3372.9           odd          4240.9
# 5          2728.3        custom          3333.4           win          3000.1
# 6          2047.0           guy          3041.0        betja_          2929.0
# 7          1937.1          bank          2972.4           bet          2860.2
# 8          1734.9           day          2803.1            na          2636.1
# 9          1730.3           get          2740.3    betja_code          2605.1

# %% [markdown]
# ### Non-negative Matrix Factorisation (NMF).

# %%
from sklearn.decomposition import NMF

# %%
model_nmf = NMF(n_components=number_of_topics, random_state=42, alpha=.1, l1_ratio=.5, verbose=True)

# %%
model_nmf.fit(tf)
# Out:
# violation: 1.0
# violation: 0.4125309653456096
# violation: 0.22587590937223354
# violation: 0.09908776087575762
# violation: 0.04728187465794097
# violation: 0.025186510707268787
# violation: 0.015004612526747016
# violation: 0.00990048329864382
# violation: 0.006980543067290575
# violation: 0.0052174143042793995
# violation: 0.004152801798311493
# violation: 0.003500578697361405
# violation: 0.0030945337193856045
# violation: 0.0028453535430729687
# violation: 0.002695012062577527
# violation: 0.0026074058560839127
# violation: 0.00255722750358941
# violation: 0.0025276251579136504
# violation: 0.0025083441833912484
# violation: 0.002494320637015608
# violation: 0.0024836594433845357
# violation: 0.0024746806092538903
# violation: 0.0024666895565368394
# violation: 0.0024593138632941895
# violation: 0.002452357650392068
# violation: 0.0024456370960473516
# violation: 0.0024390471094232246
# violation: 0.0024326288179197025
# violation: 0.0024263339757669873
# violation: 0.0024201464318963435
# violation: 0.002414113367404087
# violation: 0.002408187990297512
# violation: 0.0024023371232331147
# violation: 0.0023966108604719866
# violation: 0.0023909819320845
# violation: 0.002385463472963571
# violation: 0.002380035041134823
# violation: 0.0023746869943048693
# violation: 0.002369425434563106
# violation: 0.002364245056519087
# violation: 0.0023591468182549247
# violation: 0.002354128366155592
# violation: 0.002349171022170183
# violation: 0.0023442879801584032
# violation: 0.0023394626241298386
# violation: 0.0023347011724539034
# violation: 0.002329990450657139
# violation: 0.0023253230088932197
# violation: 0.0023207098670790095
# violation: 0.002316142737904937
# violation: 0.002311618001608365
# violation: 0.0023071331441897303
# violation: 0.002302702123927476
# violation: 0.0022983124196796754
# violation: 0.002293936816589741
# violation: 0.002289579957446932
# violation: 0.0022852607980350355
# violation: 0.0022809700140904872
# violation: 0.002276708613822043
# violation: 0.0022724760243640267
# violation: 0.0022682631391113214
# violation: 0.0022640719260871136
# violation: 0.002259907836019562
# violation: 0.002255752582593565
# violation: 0.002251615800249136
# violation: 0.002247496777586198
# violation: 0.0022433927383845673
# violation: 0.002239303439987792
# violation: 0.002235228639679099
# violation: 0.0022311666384029817
# violation: 0.0022271174729080784
# violation: 0.002223079775737957
# violation: 0.002219053744928388
# violation: 0.0022150370501920207
# violation: 0.0022110296650201602
# violation: 0.002207031120401442
# violation: 0.0022030402931725035
# violation: 0.0021990570694773726
# violation: 0.0021950803896114597
# violation: 0.0021911106067322964
# violation: 0.0021871468074992776
# violation: 0.0021831897475324364
# violation: 0.0021792381253814405
# violation: 0.002175293742450557
# violation: 0.0021713525225616503
# violation: 0.0021674148567386348
# violation: 0.0021634811488552433
# violation: 0.0021595523241561164
# violation: 0.002155626135222425
# violation: 0.002151703187350991
# violation: 0.002147783563908238
# violation: 0.0021438668019667976
# violation: 0.0021399528813449246
# violation: 0.002136043184377828
# violation: 0.0021321351253546514
# violation: 0.002128228581636114
# violation: 0.0021243247064970114
# violation: 0.002120422428493102
# violation: 0.0021165214576458927
# violation: 0.0021126231420878125
# violation: 0.002108726288725112
# violation: 0.0021048303247790537
# violation: 0.002100935972225589
# violation: 0.002097042770882553
# violation: 0.00209315111308847
# violation: 0.002089263691398588
# violation: 0.0020853756599496093
# violation: 0.0020814868348098103
# violation: 0.0020775987836870015
# violation: 0.002073712177505683
# violation: 0.002069826415684205
# violation: 0.0020659414722664837
# violation: 0.002062058006371539
# violation: 0.002058174168977421
# violation: 0.002054291269500237
# violation: 0.0020504107138148053
# violation: 0.00204652941349595
# violation: 0.002042649160214777
# violation: 0.002038771273502797
# violation: 0.0020348925973886923
# violation: 0.0020310152017893037
# violation: 0.00202713783350705
# violation: 0.0020232605431596508
# violation: 0.0020193840580790814
# violation: 0.0020155079281916973
# violation: 0.0020116324779649564
# violation: 0.002007756890410375
# violation: 0.0020038822729029973
# violation: 0.00200000842166984
# violation: 0.0019961354681987263
# violation: 0.001992261885573425
# violation: 0.001988389426014001
# violation: 0.001984517148563011
# violation: 0.001980645526231657
# violation: 0.0019767747965553513
# violation: 0.0019729043409502634
# violation: 0.001969034734522079
# violation: 0.001965165517948542
# violation: 0.001961298091881366
# violation: 0.001957430561263487
# violation: 0.0019535637819108297
# violation: 0.0019496987982994362
# violation: 0.001945833405600777
# violation: 0.001941969645860002
# violation: 0.0019381053013351275
# violation: 0.0019342416996806918
# violation: 0.0019303789853574397
# violation: 0.0019265173945673371
# violation: 0.0019226565348726796
# violation: 0.00191879758141376
# violation: 0.001914938222005832
# violation: 0.0019110812290667324
# violation: 0.001907226207716813
# violation: 0.0019033704709634637
# violation: 0.00189951540828017
# violation: 0.0018956615092140386
# violation: 0.0018918088466460682
# violation: 0.001887956981636454
# violation: 0.0018841061237166537
# violation: 0.0018802561390696595
# violation: 0.0018764073031345564
# violation: 0.0018725599647093961
# violation: 0.0018687136091577905
# violation: 0.001864868726060466
# violation: 0.0018610259752716487
# violation: 0.0018571843648060222
# violation: 0.001853344515784299
# violation: 0.0018495069821160093
# violation: 0.0018456692086852011
# violation: 0.0018418326320048162
# violation: 0.0018379969443000886
# violation: 0.0018341626504373256
# violation: 0.0018303303650414329
# violation: 0.0018264990679772964
# violation: 0.0018226693271254776
# violation: 0.0018188415891145103
# violation: 0.0018150171910886789
# violation: 0.0018111932553857386
# violation: 0.0018073705625015746
# violation: 0.0018035495175219673
# violation: 0.001799730010671168
# violation: 0.0017959121895307138
# violation: 0.0017920964332146995
# violation: 0.0017882828121855217
# violation: 0.0017844707784531641
# violation: 0.0017806603487443282
# violation: 0.0017768518276339595
# violation: 0.0017730448148898415
# violation: 0.001769240475378404
# violation: 0.0017654376605245672
# violation: 0.0017616378651528072
# violation: 0.0017578396794428986
# violation: 0.0017540440634211982
# violation: 0.0017502499690851664
# violation: 0.0017464574584157417
# violation: 0.0017426686875577396
# violation: 0.0017388819912581045
# violation: 0.0017350966082258375
# violation: 0.0017313131919219557
# violation: 0.0017275317311842584
# NMF(alpha=0.1, beta_loss='frobenius', init=None, l1_ratio=0.5, max_iter=200,
#     n_components=10, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=True)

# %%
no_top_words = 10
display_topics(model_nmf, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0             _            25.1         betja            22.7        #betja
# 1             #             1.1        _betja             3.6          #bet
# 2           odd             1.0           odd             2.8       #soccer
# 3             ₦             0.9           win             2.4          game
# 4           win             0.6           bet             2.3         #bwin
# 5          _odd             0.5          code             2.3  #williamhill
# 6          odd_             0.5          play             2.2          call
# 7        #betja             0.5          game             1.9      whatsapp
# 8            fc             0.4        betja_             1.9         admin
# 9          win_             0.4          _odd             1.8         inbox
#
#   Topic 2 weights  Topic 3 words Topic 3 weights      Topic 4 words  \
# 0             7.8        account            17.8           #bbnaija
# 1             6.4         credit             4.2             #betja
# 2             4.8              #             4.0               coin
# 3             4.0  betja_account             3.7          #bbnaija_
# 4             4.0          money             3.0              merci
# 5             3.9          debit             2.9         betja_coin
# 6             3.1             id             2.7  #bbnaija_#bbnaija
# 7             2.8        deposit             2.6              tacha
# 8             2.6            id_             2.3                ike
# 9             2.5        usernam             2.1             housem
#
#   Topic 4 weights Topic 5 words Topic 5 weights Topic 6 words Topic 6 weights  \
# 0            18.6             ’            17.3           bet             5.2
# 1             2.1            it             5.1         today             5.1
# 2             1.9        buhari             2.4           big             4.9
# 3             1.3       nigeria             2.0           win             4.7
# 4             1.2      osinbajo             1.3           now             4.4
# 5             1.2          that             1.2           ✅✅✅             4.3
# 6             1.2           let             1.1          game             3.9
# 7             1.1        presid             0.7            💥💥             3.7
# 8             1.1             –             0.7           fix             3.1
# 9             1.1           aid             0.6         match             2.9
#
#   Topic 7 words Topic 7 weights Topic 8 words Topic 8 weights Topic 9 words  \
# 0          bank            16.0         pleas            15.2            ’t
# 1        polari             3.8        _pleas             5.7           don
# 2   polari_bank             3.6         thank             5.1           can
# 3         bank_             3.6          help             4.8             u
# 4       _polari             1.7        kindli             4.0             i
# 5         first             1.2            us             3.7          didn
# 6        access             1.0         activ             3.3          know
# 7   access_bank             0.9         hello             3.2           won
# 8    first_bank             0.9        _hello             3.0          like
# 9        zenith             0.8          wawu             2.5         money
#
#   Topic 9 weights
# 0            14.2
# 1             6.0
# 2             2.2
# 3             1.8
# 4             1.7
# 5             1.5
# 6             1.3
# 7             1.1
# 8             1.1
# 9             1.0
